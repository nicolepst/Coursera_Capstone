# %% [markdown]
# # Data

# %% [markdown]
# Using Foursquare, I will look at similar Italian restaurant venues in the area, and tips from their customers. This will help locate where the owner should  open it, since the owner doesn't want to be on the same block as any other Italian restaurant. Tips from similar venues may be useful to get more business, and to get more customers from the competitor restaurants. The owner values the views of customers, and wants a nice home restaurant environment.
